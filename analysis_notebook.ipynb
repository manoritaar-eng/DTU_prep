# %%
import pandas as pd 

df = pd.read_excel('Dan Housing.xlsx')
print(df.head())
# Out:
#   Sales of real property by key figures, category of real property,  \
# 0                                    region and time
# 1                                                NaN
# 2
# 3              Average price per property (dkk 1000)
# 4
#
#           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1                NaN        NaN        NaN        NaN        NaN        NaN
# 2                                  2006M01    2006M02    2006M03    2006M04
# 3                NaN        NaN        NaN        NaN        NaN        NaN
# 4  One-family houses        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 224 Unnamed: 225  \
# 0        NaN        NaN        NaN  ...          NaN          NaN
# 1        NaN        NaN        NaN  ...          NaN          NaN
# 2    2006M05    2006M06    2006M07  ...      2024M06      2024M07
# ...
